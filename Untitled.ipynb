# %%
pip install rasterio geopandas azure-storage-blob scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 61.4 MB/s  0:00:006m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 75.9 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 85.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.4/32.4 MB 88.6 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 93.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 93.8 MB/s  0:00:00
# ...
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━  0/10 [pyproj]
#     Found existing installation: numpy 1.23.5  0/10 [pyproj]
#     Uninstalling numpy-1.23.5:━━━━━━━━━━━━━━  0/10 [pyproj]
#       Successfully uninstalled numpy-1.23.5━  0/10 [pyproj]
#   Attempting uninstall: pandas━━━━━━╺━━━━━━━━━━━  7/10 [pyogrio]]gins]
#     Found existing installation: pandas 1.5.3m━━━━━━━━━━━  7/10 [pyogrio]
#     Uninstalling pandas-1.5.3:━━━━━━━━━━╺━━━━━━━  8/10 [pandas]
# ...
